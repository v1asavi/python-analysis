# %%
import pandas as pd
import numpy as np
#generate a large volume of random data(eg. 1 millon data points)
volume_data = pd.read_csv('/content/Electric_Production.csv', delimiter=',')
print("volume of data:",len(volume_data))
# Out:
# volume of data: 397

# %%
 import time
#simulate streaming data every second for 10 seconds
velocity_data = pd.read_csv('/content/Electric_Production.csv', sep =',')
for i in range(10):
  velocity_data=np.random.rand( )#generate random data
  print("velocity data point:",velocity_data)
  time.sleep(1)#wait for 1 second to simulate real-time data stream
# Out:
# velocity data point: 0.027968215746944414
# velocity data point: 0.12943185996872197
# velocity data point: 0.12717257333774912
# velocity data point: 0.31815933814680264
# velocity data point: 0.8163408093700708
# velocity data point: 0.8555858288273944
# velocity data point: 0.47162361235596506
# velocity data point: 0.8479239220232304
# velocity data point: 0.6269966215564494
# velocity data point: 0.9592667695345968

# %%
import pandas as pd
import random
#generate some random data with noise
veracity_data = pd.read_csv('/content/Electric_Production.csv', sep =',')
veracity_data=[random.choice([1,2,3,None])for _ in range(20)]
print("veracity data:",veracity_data)
# Out:
# veracity data: [None, 3, 1, None, 2, 3, 1, 1, 2, 1, 1, None, 2, 1, 1, 1, 3, None, 1, 3]

# %%
structured_data = pd.read_csv('/content/Electric_Production.csv', sep =',')
#structured data
print(structured_data)
#semi-structured data(JSON)
semistructured_data = pd.read_csv('/content/Electric_Production.csv', sep =',')
print(semistructured_data)
#unstructured data(text)
unstructured_data="This is a sample text document.It can contain any information in free form"
# Out:
#            DATE     Value
# 0    01-01-1985   72.5052
# 1    02-01-1985   70.6720
# 2    03-01-1985   62.4502
# 3    04-01-1985   57.4714
# 4    05-01-1985   55.3151
# ..          ...       ...
# 392  09-01-2017   98.6154
# 393  10-01-2017   93.6137
# 394  11-01-2017   97.3359
# 395  12-01-2017  114.7212
# 396  01-01-2018  129.4048
#
# [397 rows x 2 columns]
#            DATE     Value
# 0    01-01-1985   72.5052
# 1    02-01-1985   70.6720
# 2    03-01-1985   62.4502
# 3    04-01-1985   57.4714
# 4    05-01-1985   55.3151
# ..          ...       ...
# 392  09-01-2017   98.6154
# 393  10-01-2017   93.6137
# 394  11-01-2017   97.3359
# 395  12-01-2017  114.7212
# 396  01-01-2018  129.4048
#
# [397 rows x 2 columns]
