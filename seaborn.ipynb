# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
diamonds=sns.load_dataset("diamonds")
print(diamonds)
g=sns.FacetGrid(diamonds,col="color")
g.map(sns.histplot, "carat")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Diamonds  Distribution by Passenger Carats")
plt.show()
diamonds.to_csv("diamondsdatabase.csv")
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
import pandas as pd
df=pd.read_csv("/content/diamondsdatabase.csv")
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df=pd.read_csv("/content/diamondsdatabase.csv")
df2=df.copy()
df2.loc[2:5,'SEM1']=1
df2.head(7)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           1   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           2   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           3   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           4   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
#
#       y     z  SEM1
# 0  3.98  2.43   NaN
# 1  3.84  2.31   NaN
# 2  4.07  2.31   1.0
# 3  4.23  2.63   1.0
# 4  4.35  2.75   1.0
# 5  3.96  2.48   1.0
# 6  3.98  2.47   NaN

# %%
print(df[df.index==1])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
mpg=sns.load_dataset("mpg")
print(mpg)
g=sns.FacetGrid(mpg,col="acceleration")
g.map(sns.histplot, "cylinders")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Diamonds  Distribution by Passenger Carats")
plt.show()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
anscombe=sns.load_dataset("anscombe")
print(anscombe)
g=sns.FacetGrid(anscombe,col="dataset")
g.map(sns.histplot, "x")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Diamonds  Distribution by Passenger Carats")
plt.show()
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
dots=sns.load_dataset("dots")
print(dots)
g=sns.FacetGrid(dots,col="coherence")
g.map(sns.histplot, "firing_rate")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Diamonds  Distribution by Passenger Carats")
plt.show()
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
attention=sns.load_dataset("attention")
print(attention)
g=sns.FacetGrid(attention,col="subject")
g.map(sns.histplot, "score")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Diamonds  Distribution by Passenger Carats")
plt.show()
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
fmri=sns.load_dataset("fmri")
print(fmri)
g=sns.FacetGrid(fmri,col="timepoint")
g.map(sns.histplot, "signal")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Diamonds  Distribution by Passenger Carats")
plt.show()
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
flights=sns.load_dataset("flights")
print(dots)
g=sns.FacetGrid(dots,col="choice")
g.map(sns.histplot, "coherence")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("flights  Distribution by Passenger Carats")
plt.show()
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
planets=sns.load_dataset("planets")
print(planets)
g=sns.FacetGrid(planets,col="number")
g.map(sns.histplot, "method")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Distribution by planets")
plt.show()
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
exercise=sns.load_dataset("exercise")
print(exercise)
g=sns.FacetGrid(exercise,col="id")
g.map(sns.histplot,"pulse")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Exercises and Pulserate")
plt.show()
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#load example dataset
attention=sns.load_dataset("attention")
print(attention)
#plt.legend(loc='best')
g=sns.FacetGrid(attention,col="subject")
g.map(sns.histplot, "score")
plt.subplots_adjust(top=0.8)
g.fig.suptitle("Diamonds  Distribution by Passenger Carats")
plt.show()
attention.to_csv("attentiondatabase.csv")
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...
