# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
df=pd.read_csv('/content/drive/MyDrive/dataset/Lpro (1).csv')
df
# Out:
#     Experience_Years  Age
# 0                  5   28
# 1                  1   21
# 2                  3   23
# 3                  2   22
# 4                  1   17
# 5                 25   62
# 6                 19   54
# 7                  2   21
# 8                 10   36
# 9                 15   54
# 10                 4   26
# 11                 6   29
# 12                14   39
# 13                11   40
# 14                 2   23
# 15                 4   27
# 16                10   34
# 17                15   54
# 18                 2   21
# 19                10   36
# 20                15   54
# 21                 4   26
# 22                 5   29
# 23                 1   21
# 24                 4   23
# 25                 3   22
# 26                 1   18
# 27                27   62
# 28                19   54
# 29                 2   21
# 30                10   34
# 31                15   54
# 32                20   55
# 33                19   53
# 34                16   49

# %%
df.head(5)
# Out:
#    Experience_Years  Age
# 0                 5   28
# 1                 1   21
# 2                 3   23
# 3                 2   22
# 4                 1   17

# %%
df.isna().sum()
# Out:
# Experience_Years    0
# Age                 0
# dtype: int64

# %%
X = df.iloc[:,:- 1].values
y = df.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state =0 )

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
print(y_train)
regressor.fit(X_train,y_train)
# Out:
# [23 29 62 22 49 55 18 34 36 40 62 54 23 54 23 21 39 54 21 17 21 26 36 54
#  21 53 22 28]
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue',label='Regression Line')
plt.title('Experience vs Age (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Age')
plt.legend()
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue',label='Regression Line')
plt.title('Experience vs Age (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Age')
plt.legend()
plt.show()
